# %%
# %%javascript
#
# IPython.OutputArea.auto_scroll_threshold = 9999

# %%
cd ../../
# Out:
# /Users/samuelcohen/Movies/Healing-POEs-ICML/Code/bayesian_benchmarks_modular

# %%
from matplotlib import pyplot
import numpy as np
import pandas
from matplotlib import pyplot as plt
from scipy.stats import rankdata
from IPython.display import display, HTML

from bayesian_benchmarks.database_utils import Database
from bayesian_benchmarks.data import  _ALL_REGRESSION_DATATSETS
ALL_DATATSETS = {}
ALL_DATATSETS.update(_ALL_REGRESSION_DATATSETS)
from bayesian_benchmarks.data import regression_datasets

# %%
def rankarray(A):
    ranks = []
    for a in A:
        ranks.append(rankdata(a))
    return np.array(ranks)


def read_regression_classification(fs, models_names, datasets, task,file='results.db'):
    if task == 'classification':
        fields = ['dataset', 'N', 'D', 'K'] + [m[1] for m in models_names]
    else:
        fields = ['dataset', 'N', 'D'] + [m[1] for m in models_names]

    results = {}
    for f in fs:
        results[f] = {'table':{f:[] for f in fields}, 'vals':[]}

    with Database('bayesian_benchmarks/results/'+file) as db:

        for dataset in datasets:
            for f in fs:
                results[f]['table']['dataset'].append(dataset[:10])
                results[f]['table']['N'].append(ALL_DATATSETS[dataset].N)
                results[f]['table']['D'].append(ALL_DATATSETS[dataset].D)
                if task == 'classification':
                    results[f]['table']['K'].append(ALL_DATATSETS[dataset].K)

            row = {f:[] for f in fs}
            for model, name in models_names:
                res = db.read(task, fs, {'model':model, 
                                         'dataset':dataset})
                print(model,dataset,len(res))
                if len(res) == 0:
                    for f in fs:
                        results[f]['table'][name].append('')
                        row[f].append(np.nan)
                else:
                    for i, f in enumerate(fs):
                        if f=='test_loglik':
                            L = [-float(l[i]) for l in res]
                        else:
                            L = [float(l[i]) for l in res]
                        m = np.average(L)
                        std = np.std(L) if len(L) > 1 else np.nan
                        if m < 1000 and m > -1000:
                            r = '{:.3f}({:.3f})'.format(m, std)
                            row[f].append(m)
                        else:
                            r = 'nan'
                            row[f].append(np.nan)

                        results[f]['table'][name].append(r)

            #             stderr = np.std(L)/float(len(L))**0.5
            #             r = '{:.3f} ({:.3f})'.format(m, stderr)
            for f in fs:   
                results[f]['vals'].append(row[f])


    for f in fs:
        if 'unnormalized' not in f:
            vals = np.array(results[f]['vals'])

            avgs = np.nanmean(vals, 0)
            meds = np.nanmedian(vals, 0)
            rks = np.nanmean(rankarray(vals), 0)

            for s, n in [[avgs, 'avg'], [meds, 'median'], [rks, 'avg rank']]:
                results[f]['table']['dataset'].append(n)
                results[f]['table']['N'].append('')
                results[f]['table']['D'].append('')
                if task == 'classification':
                    results[f]['table']['K'].append('')
                for ss, name in zip(s, [m[1] for m in models_names]):
                    results[f]['table'][name].append('{:.3f}'.format(ss))
    
    return results, fields

# %%
models_names = [
                ['gPoE_100_100_clustering_variance', 'rBCM/gPoE_var'],
               ['bar_100_100_clustering_variance', 'bar_var'],
               ['rBCM_100_100_clustering_diff_entr', 'rbcm_entr'],
               ['gp', 'gp'],
               ['linear', 'linear']]
                

fs = 'test_loglik', 'test_rmse', 'test_loglik_unnormalized', 'test_rmse_unnormalized'

results, fields = read_regression_classification(fs, models_names, regression_datasets, 'regression')
# Out:
# gPoE_100_100_clustering_variance airline 10
# bar_100_100_clustering_variance airline 10
# rBCM_100_100_clustering_diff_entr airline 10
# gp airline 0
# linear airline 10
# gPoE_100_100_clustering_variance concrete 10
# bar_100_100_clustering_variance concrete 10
# rBCM_100_100_clustering_diff_entr concrete 10
# gp concrete 0
# linear concrete 10
# gPoE_100_100_clustering_variance power 10
# bar_100_100_clustering_variance power 10
# rBCM_100_100_clustering_diff_entr power 10
# gp power 0
# linear power 10
# gPoE_100_100_clustering_variance wilson_airfoil 10
# bar_100_100_clustering_variance wilson_airfoil 10
# rBCM_100_100_clustering_diff_entr wilson_airfoil 10
# gp wilson_airfoil 0
# linear wilson_airfoil 10
# gPoE_100_100_clustering_variance wilson_kin40k 10
# bar_100_100_clustering_variance wilson_kin40k 10
# rBCM_100_100_clustering_diff_entr wilson_kin40k 10
# gp wilson_kin40k 0
# linear wilson_kin40k 10
# gPoE_100_100_clustering_variance wilson_parkinsons 10
# bar_100_100_clustering_variance wilson_parkinsons 10
# rBCM_100_100_clustering_diff_entr wilson_parkinsons 10
# gp wilson_parkinsons 0
# linear wilson_parkinsons 10
# gPoE_100_100_clustering_variance wilson_protein 10
# bar_100_100_clustering_variance wilson_protein 10
# rBCM_100_100_clustering_diff_entr wilson_protein 10
# gp wilson_protein 0
# linear wilson_protein 10
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:64: RuntimeWarning: Mean of empty slice

# %%
print('NLPDSd')
display(HTML(pandas.DataFrame(results['test_loglik']['table'], columns=fields).to_html(index=False)))


print('normalised test rmse')
display(HTML(pandas.DataFrame(results['test_rmse']['table'], columns=fields).to_html(index=False)))
# Out:
# normalised test loglikelihood
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset</th>
#       <th>N</th>
#       <th>D</th>
#       <th>rBCM/gPoE_var</th>
#       <th>bar_var</th>
#       <th>rbcm_entr</th>
#       <th>gp</th>
#       <th>linear</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>airline</td>
#       <td>800000</td>
#       <td>7</td>
#       <td>1.318(0.014)</td>
#       <td>1.318(0.014)</td>
#       <td>1.311(0.014)</td>
#       <td></td>
#       <td>1.388(0.012)</td>
#     </tr>
#     <tr>
#       <td>concrete</td>
#       <td>1030</td>
#       <td>8</td>
#       <td>0.290(0.078)</td>
#       <td>0.290(0.078)</td>
#       <td>0.295(0.090)</td>
#       <td></td>
#       <td>0.953(0.052)</td>
#     </tr>
#     <tr>
#       <td>power</td>
#       <td>9568</td>
#       <td>4</td>
#       <td>-0.083(0.036)</td>
#       <td>-0.076(0.033)</td>
#       <td>-0.078(0.038)</td>
#       <td></td>
#       <td>0.098(0.031)</td>
#     </tr>
#     <tr>
#       <td>wilson_air</td>
#       <td>1503</td>
#       <td>5</td>
#       <td>0.414(0.104)</td>
#       <td>0.414(0.104)</td>
#       <td>0.411(0.112)</td>
#       <td></td>
#       <td>1.096(0.070)</td>
#     </tr>
#     <tr>
#       <td>wilson_kin</td>
#       <td>40000</td>
#       <td>8</td>
#       <td>-0.326(0.011)</td>
#       <td>-0.335(0.010)</td>
#       <td>0.388(0.077)</td>
#       <td></td>
#       <td>1.419(0.013)</td>
#     </tr>
#     <tr>
#       <td>wilson_par</td>
#       <td>5875</td>
#       <td>20</td>
#       <td>0.098(0.065)</td>
#       <td>0.097(0.065)</td>
#       <td>0.166(0.106)</td>
#       <td></td>
#       <td>1.282(0.025)</td>
#     </tr>
#     <tr>
#       <td>wilson_pro</td>
#       <td>45730</td>
#       <td>9</td>
#       <td>0.779(0.009)</td>
#       <td>0.778(0.009)</td>
#       <td>0.801(0.010)</td>
#       <td></td>
#       <td>1.252(0.009)</td>
#     </tr>
#     <tr>
#       <td>avg</td>
#       <td></td>
#       <td></td>
#       <td>0.356</td>
#       <td>0.355</td>
#       <td>0.471</td>
#       <td>nan</td>
#       <td>1.070</td>
#     </tr>
#     <tr>
#       <td>median</td>
#       <td></td>
#       <td></td>
#       <td>0.290</td>
#       <td>0.290</td>
#       <td>0.388</td>
#       <td>nan</td>
#       <td>1.252</td>
#     </tr>
#     <tr>
#       <td>avg rank</td>
#       <td></td>
#       <td></td>
#       <td>1.857</td>
#       <td>1.857</td>
#       <td>2.286</td>
#       <td>5.000</td>
#       <td>4.000</td>
#     </tr>
#   </tbody>
# </table>
# normalised test rmse
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset</th>
#       <th>N</th>
#       <th>D</th>
#       <th>rBCM/gPoE_var</th>
#       <th>bar_var</th>
#       <th>rbcm_entr</th>
#       <th>gp</th>
#       <th>linear</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>airline</td>
#       <td>800000</td>
#       <td>7</td>
#       <td>0.908(0.013)</td>
#       <td>0.908(0.013)</td>
#       <td>0.902(0.013)</td>
#       <td></td>
#       <td>0.969(0.012)</td>
#     </tr>
#     <tr>
#       <td>concrete</td>
#       <td>1030</td>
#       <td>8</td>
#       <td>0.344(0.029)</td>
#       <td>0.344(0.029)</td>
#       <td>0.345(0.027)</td>
#       <td></td>
#       <td>0.626(0.031)</td>
#     </tr>
#     <tr>
#       <td>power</td>
#       <td>9568</td>
#       <td>4</td>
#       <td>0.222(0.008)</td>
#       <td>0.224(0.008)</td>
#       <td>0.223(0.008)</td>
#       <td></td>
#       <td>0.267(0.008)</td>
#     </tr>
#     <tr>
#       <td>wilson_air</td>
#       <td>1503</td>
#       <td>5</td>
#       <td>0.351(0.038)</td>
#       <td>0.351(0.038)</td>
#       <td>0.359(0.037)</td>
#       <td></td>
#       <td>0.721(0.047)</td>
#     </tr>
#     <tr>
#       <td>wilson_kin</td>
#       <td>40000</td>
#       <td>8</td>
#       <td>0.188(0.002)</td>
#       <td>0.185(0.002)</td>
#       <td>0.191(0.003)</td>
#       <td></td>
#       <td>1.000(0.013)</td>
#     </tr>
#     <tr>
#       <td>wilson_par</td>
#       <td>5875</td>
#       <td>20</td>
#       <td>0.337(0.030)</td>
#       <td>0.336(0.030)</td>
#       <td>0.337(0.026)</td>
#       <td></td>
#       <td>0.871(0.021)</td>
#     </tr>
#     <tr>
#       <td>wilson_pro</td>
#       <td>45730</td>
#       <td>9</td>
#       <td>0.582(0.006)</td>
#       <td>0.582(0.006)</td>
#       <td>0.608(0.008)</td>
#       <td></td>
#       <td>0.847(0.008)</td>
#     </tr>
#     <tr>
#       <td>avg</td>
#       <td></td>
#       <td></td>
#       <td>0.419</td>
#       <td>0.419</td>
#       <td>0.424</td>
#       <td>nan</td>
#       <td>0.757</td>
#     </tr>
#     <tr>
#       <td>median</td>
#       <td></td>
#       <td></td>
#       <td>0.344</td>
#       <td>0.344</td>
#       <td>0.345</td>
#       <td>nan</td>
#       <td>0.847</td>
#     </tr>
#     <tr>
#       <td>avg rank</td>
#       <td></td>
#       <td></td>
#       <td>1.857</td>
#       <td>1.571</td>
#       <td>2.571</td>
#       <td>5.000</td>
#       <td>4.000</td>
#     </tr>
#   </tbody>
# </table>
